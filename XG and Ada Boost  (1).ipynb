# %%
import pandas as pd

# %%
# !pip install xlrd

# %%
df = pd.read_excel("C:\\Users\\Home\\global_superstore\\Global Superstore.xls")

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2013-05-11 21:26:49.155781120
# min        1.00000            2011-01-01 00:00:00
# 25%    12823.25000            2012-06-19 00:00:00
# 50%    25645.50000            2013-07-08 00:00:00
# 75%    38467.75000            2014-05-22 00:00:00
# max    51290.00000            2014-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date   Postal Code         Sales  \
# count                          51290   9994.000000  51290.000000
# mean   2013-05-15 20:42:42.745174528  55190.379428    246.490581
# min              2011-01-03 00:00:00   1040.000000      0.444000
# 25%              2012-06-23 00:00:00  23223.000000     30.758625
# 50%              2013-07-12 00:00:00  56430.500000     85.053000
# 75%              2014-05-26 00:00:00  90008.000000    251.053200
# ...

# %%
df.describe(include = 'object')
# Out:
#               Order ID       Ship Mode Customer ID    Customer Name   Segment  \
# count            51290           51290       51290            51290     51290
# unique           25035               4        1590              795         3
# top     CA-2014-100111  Standard Class    PO-18850  Muhammed Yedwab  Consumer
# freq                14           30775          97              108     26518
#
#                  City       State        Country Market   Region  \
# count           51290       51290          51290  51290    51290
# unique           3636        1094            147      7       13
# top     New York City  California  United States   APAC  Central
# freq              915        2001           9994  11002    11117
#
#              Product ID         Category Sub-Category Product Name  \
# count             51290            51290        51290        51290
# unique            10292                3           17         3788
# ...

# %%
numerical_df = df.select_dtypes(include = ['number'])
numerical_df.head()
# Out:
#    Row ID  Postal Code     Sales  Quantity  Discount    Profit  Shipping Cost
# 0   32298      10024.0  2309.650         7       0.0  762.1845         933.57
# 1   26341          NaN  3709.395         9       0.1 -288.7650         923.63
# 2   25330          NaN  5175.171         9       0.1  919.9710         915.49
# 3   13524          NaN  2892.510         5       0.1  -96.5400         910.16
# 4   47221          NaN  2832.960         8       0.0  311.5200         903.04

# %%
# Try accessing the 'Order Date' column again
df['Order Date'] = pd.to_datetime(df['Order Date'])
#df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df['Day'] = df['Order Date'].dt.day
df['Day of Week'] = df['Order Date'].dt.strftime('%A')
df['Day of Week'] = df['Order Date'].dt.dayofweek

# Define a function to classify the day of the week
def classify_day(day):
    if day < 5:  # Monday to Friday (0 to 4)
        return 'Weekday'
    else:        # Saturday or Sunday (5 or 6)
        return 'Holiday'

# Apply the function to the 'Day of Week' column to get 'Weekday' or 'Weekend'
df['Day Type'] = df['Day of Week'].apply(classify_day)

# %%
df.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#       Sales  Quantity Discount    Profit Shipping Cost Order Priority Month  \
# ...

# %%
df = df.drop(['Ship Date','Order Date'],axis = 1)

# %%
df.shape
# Out:
# (51290, 26)

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
cat_cols = df.select_dtypes(include = ['object']).columns
for col in cat_cols:
     df[col] = label.fit_transform(df[col])

df.head()
# Out:
#    Row ID  Order ID  Ship Mode  Customer ID  Customer Name  Segment  City  \
# 0   32298      1499          1         1286            632        0  2290
# 1   26341     13063          2          808            413        1  3518
# 2   25330     12983          0          336            181        0   497
# 3   13524      6813          0          873            424        2   375
# 4   47221     21702          1         1290            632        0   857
#
#    State  Country  Postal Code  ...     Sales  Quantity  Discount    Profit  \
# 0    703      139      10024.0  ...  2309.650         7       0.0  762.1845
# 1    702        6          NaN  ...  3709.395         9       0.1 -288.7650
# 2    820        6          NaN  ...  5175.171         9       0.1  919.9710
# 3    145       47          NaN  ...  2892.510         5       0.1  -96.5400
# 4    270      110          NaN  ...  2832.960         8       0.0  311.5200
#
# ...

# %%
X = df.drop(['Profit'], axis =1)
y = df['Profit']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
# instantiate the DecisionTreeRegressor model with criterion MSE
from sklearn.ensemble import AdaBoostRegressor
abc=AdaBoostRegressor(n_estimators=150,learning_rate=0.01,random_state=42)
model1 =abc.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 4
#       2 from sklearn.ensemble import AdaBoostRegressor
#       3 abc=AdaBoostRegressor(n_estimators=150,learning_rate=0.01,random_state=42)
# ----> 4 model1 =abc.fit(X_train,y_train)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:133, in BaseWeightBoosting.fit(self, X, y, sample_weight)
# ...

# %%
#Predict the response for test dataset
y_train_pred = model1.predict(X_train)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from math import sqrt

# Evaluate the model
mae = mean_absolute_error(y_train, y_train_pred)
mse = mean_squared_error(y_train, y_train_pred)
rmse = sqrt(mse)

r2 = r2_score(y_train, y_train_pred)# test accuracy

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error", rmse)
print("R-squared:", r2)

# %%
#Predict the response for test dataset
y_pred = model1.predict(X_test)

# %%
# Evaluate the model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)# test accuracy
rmse = sqrt(mse)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error", rmse)

print("R-squared:", r2)

# %% [markdown]
# # XGBoost model predictions

# %%
pip install xgboost
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB 259.2 kB/s eta 0:06:25
#    ---------------------------------------- 0.0/99.8 MB 279.3 kB/s eta 0:05:58
#    ---------------------------------------- 0.1/99.8 MB 652.2 kB/s eta 0:02:33
#    ---------------------------------------- 0.3/99.8 MB 1.6 MB/s eta 0:01:04
#    ---------------------------------------- 0.6/99.8 MB 2.6 MB/s eta 0:00:38
#    ---------------------------------------- 1.0/99.8 MB 3.8 MB/s eta 0:00:26
#     --------------------------------------- 1.6/99.8 MB 4.9 MB/s eta 0:00:20
#     --------------------------------------- 2.2/99.8 MB 6.2 MB/s eta 0:00:16
#    - -------------------------------------- 2.8/99.8 MB 6.7 MB/s eta 0:00:15
# ...

# %%
import xgboost as xgb
xgb_regressor = xgb.XGBRegressor(objective ='reg:squarederror', 
                                  colsample_bytree = 0.3, 
                                  learning_rate = 0.1,
                                  max_depth = 5, 
                                  alpha = 10, 
                                  n_estimators = 100)
xgb_regressor.fit(X_train, y_train)
# Out:
# XGBRegressor(alpha=10, base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.3, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
#Predict the response for test dataset
y_train_pred1 = xgb_regressor.predict(X_train)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from math import sqrt

# Evaluate the model
mae = mean_absolute_error(y_train, y_train_pred1)
mse = mean_squared_error(y_train, y_train_pred1)
rmse = sqrt(mse)

r2 = r2_score(y_train, y_train_pred1)# test accuracy

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error", rmse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 34.00803246245852
# Mean Squared Error: 5281.08081782181
# Root Mean Squared Error 72.67104525064856
# R-squared: 0.8325537883060183

# %%
#Predict the response for test dataset
y_pred1 = xgb_regressor.predict(X_test)

# %%
# Evaluate the model
mae = mean_absolute_error(y_test, y_pred1)
mse = mean_squared_error(y_test, y_pred1)
r2 = r2_score(y_test, y_pred1)# test accuracy
rmse = sqrt(mse)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error", rmse)

print("R-squared:", r2)
# Out:
# Mean Absolute Error: 39.856275607770385
# Mean Squared Error: 12399.627382339519
# Root Mean Squared Error 111.35361414134486
# R-squared: 0.5527236692806557
