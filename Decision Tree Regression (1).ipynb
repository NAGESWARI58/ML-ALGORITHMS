# %%
import pandas as pd
import numpy as np
# !pip install xlrd

# %%
df = pd.read_excel("C:\\Users\\DELL\\Downloads\\Global Superstore.xls")
print(df)
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
df
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
df.size
# Out:
# 1230960

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
df.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
df.tail()
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 51285   29002   IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398  US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470  US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596  MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147  MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment      City       State  ...  \
# 51285    KE-16420   Katrina Edelman    Corporate      Kure   Hiroshima  ...
# 51286    ZC-21910  Zuschuss Carroll     Consumer   Houston       Texas  ...
# 51287    LB-16795    Laurel Beltran  Home Office    Oxnard  California  ...
# 51288    RB-19795        Ross Baird  Home Office  Valinhos   São Paulo  ...
# 51289    MC-18100     Mick Crebagga     Consumer  Tipitapa     Managua  ...
#
#             Product ID         Category Sub-Category  \
# ...

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2013-05-11 21:26:49.155781120
# min        1.00000            2011-01-01 00:00:00
# 25%    12823.25000            2012-06-19 00:00:00
# 50%    25645.50000            2013-07-08 00:00:00
# 75%    38467.75000            2014-05-22 00:00:00
# max    51290.00000            2014-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date   Postal Code         Sales  \
# count                          51290   9994.000000  51290.000000
# mean   2013-05-15 20:42:42.745174528  55190.379428    246.490581
# min              2011-01-03 00:00:00   1040.000000      0.444000
# 25%              2012-06-23 00:00:00  23223.000000     30.758625
# 50%              2013-07-12 00:00:00  56430.500000     85.053000
# 75%              2014-05-26 00:00:00  90008.000000    251.053200
# ...

# %%
df.describe(include="object")
# Out:
#               Order ID       Ship Mode Customer ID    Customer Name   Segment  \
# count            51290           51290       51290            51290     51290
# unique           25035               4        1590              795         3
# top     CA-2014-100111  Standard Class    PO-18850  Muhammed Yedwab  Consumer
# freq                14           30775          97              108     26518
#
#                  City       State        Country Market   Region  \
# count           51290       51290          51290  51290    51290
# unique           3636        1094            147      7       13
# top     New York City  California  United States   APAC  Central
# freq              915        2001           9994  11002    11117
#
#              Product ID         Category Sub-Category Product Name  \
# count             51290            51290        51290        51290
# unique            10292                3           17         3788
# ...

# %%
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    51290
# Name: count, dtype: int64

# %%
a=df.describe()
a.columns
# Out:
# Index(['Row ID', 'Order Date', 'Ship Date', 'Postal Code', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost'],
#       dtype='object')

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
# sns.boxplot(x='Sales',data=df)

# %%
# sns.histplot(x='Sales',data=df,kde = True,bins=20)

# %%
# sns.histplot(np.log10(df['Sales']),kde=True,fill=True,bins=50)

# %%
# sns.boxplot(x='Profit',data=df)

# %%
# sns.histplot(x='Profit',data=df,kde = True,bins=20)

# %%
#sns.histplot(np.log10(df['Profit']),kde=True,fill=True,bins=20)

# %%
# df['Profit'].skew()

# %%
# sns.boxplot(x='Shipping Cost',data=df)

# %%
# sns.histplot(x='Shipping Cost',data=df,kde = True,bins=20)

# %%
#sns.histplot(np.log10(df['Shipping Cost']),kde=True,fill=True,bins=20)

# %%
# df['Shipping Cost'].skew()

# %%
# !pip install feature_engine

# %%
pip install --upgrade feature-engine
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from feature_engine.outliers import Winsorizer

# %%
winsor = Winsorizer(capping_method = 'quantiles', tail='both',variables=['Profit'])

# %%
winsor.fit(df)
# Out:
# Winsorizer(capping_method='quantiles', fold=0.05, tail='both',
#            variables=['Profit'])

# %%
clearned_data = winsor.transform(df)

# %%
# sns.histplot(x='Profit',data=clearned_data,kde = True,bins=20)

# %%
clearned_data['Profit'].skew()
# Out:
# 1.3376129556012564

# %%
from scipy.stats import boxcox

# %%
transformed_data,_= boxcox(df['Shipping Cost'])

# %%
winsor = Winsorizer(capping_method = 'quantiles', tail='both',variables=['Shipping Cost'])

# %%
winsor.fit(df)
# Out:
# Winsorizer(capping_method='quantiles', fold=0.05, tail='both',
#            variables=['Shipping Cost'])

# %%
clearned_data = winsor.transform(df)

# %%
# sns.histplot(x='Shipping Cost',data=clearned_data,kde = True,bins=20)

# %%
# clearned_data['Shipping Cost'].skew()

# %%
c= df.describe(include="object")

# %%
c.columns
# Out:
# Index(['Order ID', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Order Priority'],
#       dtype='object')

# %%
# sns.countplot(x='Ship Mode',data=df)

# %%
# sns.countplot(x='Segment',data=df)

# %%
# sns.countplot(x='Market',data=df)

# %%
# plt.figure(figsize=[15,5])
# sns.countplot(x='Region',data=df)

# %%
# sns.countplot(x='Category',data=df)

# %%
# plt.figure(figsize=[15,5])
# sns.countplot(x='Sub-Category',data=df)

# %%
# sns.countplot(x='Category',data=df)

# %%
selected_columns = df[['City', 'Postal Code']]
result_dict = selected_columns.set_index('City').to_dict()['Postal Code']

print(result_dict)
# Out:
# {'New York City': 10024.0, 'Wollongong': nan, 'Brisbane': nan, 'Berlin': nan, 'Dakar': nan, 'Sydney': nan, 'Porirua': nan, 'Hamilton': 45011.0, 'Sacramento': 95823.0, 'Concord': 94521.0, 'Alexandria': nan, 'Kabul': nan, 'Jizan': nan, 'Toledo': 43615.0, 'Mudanjiang': nan, 'Paris': nan, 'Henderson': 42420.0, 'Prato': nan, 'Townsville': nan, 'Uvinza': nan, 'Bytom': nan, 'Chicago': 60610.0, 'Suzhou': nan, 'Edinburgh': nan, 'Juárez': nan, 'Soyapango': nan, 'Taipei': nan, 'Leipzig': nan, 'Los Angeles': 90045.0, 'Surat': nan, 'Santo Domingo': nan, 'Saint-Brieuc': nan, 'Amarillo': 79109.0, 'Gold Coast': nan, 'Fresno': 93727.0, 'Kamina': nan, 'Burlington': 27217.0, 'Stockton-on-Tees': nan, 'Mataram': nan, 'Gorakhpur': nan, 'Thiruvananthapuram': nan, 'Huddersfield': nan, 'Minneapolis': 55407.0, 'Montreuil': nan, 'Shouguang': nan, 'Jamshedpur': nan, 'Paysandú': nan, 'Behshahr': nan, 'Huntington Beach': 92646.0, 'Maputo': nan, 'Bhopal': nan, 'Seattle': 98103.0, 'Delhi': nan, 'Geraldton': nan, 'T
# ...

# %%
df['Postal Code'].value_counts()
# Out:
# Postal Code
# 10035.0    263
# 10024.0    230
# 10009.0    229
# 94122.0    203
# 10011.0    193
#           ...
# 92399.0      1
# 21740.0      1
# 57401.0      1
# 29730.0      1
# 83501.0      1
# Name: count, Length: 631, dtype: int64

# %%
null_postal_codes = df[df['Postal Code'].isnull()]

sum_null_per_city = null_postal_codes.groupby('City').size()

print("Null postal codes per city:")
print(sum_null_per_city)
# Out:
# Null postal codes per city:
# City
# Aachen                   17
# Aalen                     1
# Aalst                     4
# Aba                      25
# Abadan                   11
#                          ..
# Zwedru                    1
# Zwickau                   3
# Zwolle                    2
# eMbalenhle                2
# Águas Lindas de Goiás     4
# Length: 3139, dtype: int64

# %%
null_counts_per_city = {}
for city in df['City'].unique():
    # Count the number of null postal codes for the current city
    null_count = df[df['City'] == city]['Postal Code'].isnull().sum()
    # Store the count in the dictionary
    null_counts_per_city[city] = null_count

print("Null postal codes per city:")
null_counts_per_city
# Out:
# Null postal codes per city:
# {'New York City': 0,
#  'Wollongong': 131,
#  'Brisbane': 178,
#  'Berlin': 217,
#  'Dakar': 85,
#  'Sydney': 271,
#  'Porirua': 24,
#  'Hamilton': 28,
#  'Sacramento': 0,
#  'Concord': 0,
#  'Alexandria': 107,
#  'Kabul': 41,
#  'Jizan': 11,
#  'Toledo': 6,
#  'Mudanjiang': 6,
#  'Paris': 187,
#  'Henderson': 0,
#  'Prato': 11,
#  'Townsville': 39,
#  'Uvinza': 7,
#  'Bytom': 5,
#  'Chicago': 0,
#  'Suzhou': 61,
#  'Edinburgh': 44,
#  'Juárez': 114,
#  'Soyapango': 127,
#  'Taipei': 14,
#  'Leipzig': 39,
#  'Los Angeles': 0,
#  'Surat': 30,
#  'Santo Domingo': 443,
#  'Saint-Brieuc': 5,
#  'Amarillo': 0,
#  'Gold Coast': 201,
#  'Fresno': 0,
#  'Kamina': 1,
#  'Burlington': 1,
#  'Stockton-on-Tees': 9,
#  'Mataram': 8,
#  'Gorakhpur': 34,
#  'Thiruvananthapuram': 9,
#  'Huddersfield': 12,
#  'Minneapolis': 0,
#  'Montreuil': 19,
#  'Shouguang': 4,
#  'Jamshedpur': 6,
#  'Paysandú': 1,
#  'Behshahr': 1,
#  'Huntington Beach': 0,
#  'Maputo': 29,
# ...

# %%
df['Postal Code'] = df.groupby('City')['Postal Code'].fillna(method='ffill')

# Backward fill any remaining null values in 'Postal Code' column
df['Postal Code'] = df.groupby('City')['Postal Code'].fillna(method='bfill')

print(df)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3416\4082795688.py:1: FutureWarning: SeriesGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use Series.fillna instead
#   df['Postal Code'] = df.groupby('City')['Postal Code'].fillna(method='ffill')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3416\4082795688.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Postal Code'] = df.groupby('City')['Postal Code'].fillna(method='ffill')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3416\4082795688.py:4: FutureWarning: SeriesGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use Series.fillna instead
# ...

# %%
df['Postal Code'].isnull()
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 51285     True
# 51286    False
# 51287    False
# 51288     True
# 51289     True
# Name: Postal Code, Length: 51290, dtype: bool

# %%
df['Postal Code'].isnull().sum()
# Out:
# 40340

# %%
global_mode={}
# Fill null values with the global mode
df['Postal Code'] = df['Postal Code'].fillna(global_mode)

# Display the updated DataFrame
print(df)
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
df['Postal Code'].isnull().sum()
# Out:
# 40340

# %%
# /df['Postal Code'] = df.groupby('City')['Postal Code'].transform(lambda x: x.fillna(x.mode()[0]))

# %%
grouped = df.groupby('City')['Postal Code']

# %%
def fill_with_mode(group):
    mode_values = group.mode()
    if not mode_values.empty:
        mode_value = mode_values.iloc[0]  # Get the first mode value
        return group.fillna(mode_value)
    else:
        return group

# %%
df['Postal Code'] = grouped.transform(fill_with_mode)
df['Postal Code']
# Out:
# 0        10024.0
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 51285        NaN
# 51286    77095.0
# 51287    93030.0
# 51288        NaN
# 51289        NaN
# Name: Postal Code, Length: 51290, dtype: float64

# %%
#print(df)

# %%
#  df['Postal Code'] = df.groupby('City')['Postal Code'].transform(lambda x: x.fillna(x.mode()[0]))

# %%
df['Postal Code'] = df['Postal Code'].fillna(global_mode)

# %%
df['Postal Code']
# Out:
# 0        10024.0
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 51285        NaN
# 51286    77095.0
# 51287    93030.0
# 51288        NaN
# 51289        NaN
# Name: Postal Code, Length: 51290, dtype: float64

# %%
df['Postal Code'].isnull()
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 51285     True
# 51286    False
# 51287    False
# 51288     True
# 51289     True
# Name: Postal Code, Length: 51290, dtype: bool

# %%
df['Postal Code'].isnull().sum()
# Out:
# 40340

# %%
df['Postal Code'].value_counts()
# Out:
# Postal Code
# 10035.0    263
# 32935.0    235
# 10024.0    230
# 10009.0    229
# 94122.0    203
#           ...
# 80122.0      1
# 61821.0      1
# 7036.0       1
# 80022.0      1
# 83501.0      1
# Name: count, Length: 631, dtype: int64

# %%
city_mode = df.groupby('City')['Postal Code'].apply(lambda x: x.mode()[0] if not x.mode().empty else np.nan)

# %%
df['Postal Code'] = df.apply(lambda row: city_mode[row['City']] if pd.isnull(row['Postal Code']) else row['Postal Code'], axis=1)

# %%
df['Postal Code']
# Out:
# 0        10024.0
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 51285        NaN
# 51286    77095.0
# 51287    93030.0
# 51288        NaN
# 51289        NaN
# Name: Postal Code, Length: 51290, dtype: float64

# %%
df['Postal Code'].isnull()
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 51285     True
# 51286    False
# 51287    False
# 51288     True
# 51289     True
# Name: Postal Code, Length: 51290, dtype: bool

# %%
df['Postal Code'].isnull().sum()
# Out:
# 40340

# %%
# df.describe()

# %%
#df['Postal Code'].value_counts()

# %%
#global_mode = df['Postal Code'].mode()[0]

# %%
#df['Postal Code'] = df['Postal Code'].fillna(global_mode)

# %%
#df['Postal Code']

# %%
#df['Postal Code'].isnull()

# %%
#df['Postal Code'].isnull().sum()

# %%
#df['Postal Code'].value_counts()

# %%
#df['Postal Code'].value_counts()

# %%
df= df.drop(columns=['Postal Code'])

# %%
df
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# ...

# %%
import numpy as np
import pandas as pd


# Convert data into a DataFrame
df = pd.DataFrame(df)

# Filter out only numerical columns
numerical_cols = df.select_dtypes(include=[np.number])

# Calculate the first quartile (Q1) for each numerical column
q1 = numerical_cols.quantile(0.25)

# Calculate the third quartile (Q3) for each numerical column
q3 = numerical_cols.quantile(0.75)

# Calculate the interquartile range (IQR) for each numerical column
iqr = q3 - q1

print("First Quartile (Q1):")
print(q1)
print("\nThird Quartile (Q3):")
print(q3)
print("\nInterquartile Range (IQR):")
print(iqr)
# Out:
# First Quartile (Q1):
# Row ID           12823.250000
# Sales               30.758625
# Quantity             2.000000
# Discount             0.000000
# Profit               0.000000
# Shipping Cost        2.610000
# Name: 0.25, dtype: float64
#
# Third Quartile (Q3):
# Row ID           38467.7500
# Sales              251.0532
# Quantity             5.0000
# Discount             0.2000
# Profit              36.8100
# Shipping Cost       24.4500
# Name: 0.75, dtype: float64
#
# Interquartile Range (IQR):
# Row ID           25644.500000
# Sales              220.294575
# Quantity             3.000000
# Discount             0.200000
# Profit              36.810000
# Shipping Cost       21.840000
# dtype: float64

# %%
# Define the lower and upper bounds for outlier detection
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Identify outliers for each numerical column
outliers = (numerical_cols < lower_bound) | (numerical_cols > upper_bound)

# Count the number of outliers in each numerical column
num_outliers = outliers.sum()

print("Number of outliers in each numerical column:")
print(num_outliers)

# Remove rows containing outliers
df_data= df[~outliers.any(axis=1)]

print("\nDataFrame after removing outliers:")
df_data
# Out:
# Number of outliers in each numerical column:
# Row ID              0
# Sales            5655
# Quantity          877
# Discount         4172
# Profit           9755
# Shipping Cost    5909
# dtype: int64
#
# DataFrame after removing outliers:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 5909    31907  CA-2013-161816 2013-04-29 2013-05-02     First Class
# 5914    24261   ID-2013-79432 2013-12-11 2013-12-14    Second Class
# 5915    33355  CA-2014-120376 2014-12-23 2014-12-26     First Class
# 5921    24245   IN-2014-22606 2014-08-11 2014-08-11        Same Day
# 5922    30952   ID-2014-85529 2014-05-08 2014-05-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 51284   24175   IN-2014-57662 2014-08-05 2014-08-10  Standard Class
# 51285   29002   IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51287   40470  US-2013-155768 2013-12-02 2013-12-02        Same Day
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36311 entries, 5909 to 51289
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          36311 non-null  int64
#  1   Order ID        36311 non-null  object
#  2   Order Date      36311 non-null  datetime64[ns]
#  3   Ship Date       36311 non-null  datetime64[ns]
#  4   Ship Mode       36311 non-null  object
#  5   Customer ID     36311 non-null  object
#  6   Customer Name   36311 non-null  object
#  7   Segment         36311 non-null  object
#  8   City            36311 non-null  object
#  9   State           36311 non-null  object
#  10  Country         36311 non-null  object
#  11  Market          36311 non-null  object
#  12  Region          36311 non-null  object
#  13  Product ID      36311 non-null  object
#  14  Category        36311 non-null  object
#  15  Sub-Category    36311 non-null  object
#  16  Product Name    36311 non-null  object
# ...

# %%
df.describe(include="object")
# Out:
#               Order ID       Ship Mode Customer ID    Customer Name   Segment  \
# count            51290           51290       51290            51290     51290
# unique           25035               4        1590              795         3
# top     CA-2014-100111  Standard Class    PO-18850  Muhammed Yedwab  Consumer
# freq                14           30775          97              108     26518
#
#                  City       State        Country Market   Region  \
# count           51290       51290          51290  51290    51290
# unique           3636        1094            147      7       13
# top     New York City  California  United States   APAC  Central
# freq              915        2001           9994  11002    11117
#
#              Product ID         Category Sub-Category Product Name  \
# count             51290            51290        51290        51290
# unique            10292                3           17         3788
# ...

# %%
df_data = df_data.copy()

df_data['Order Date'] = pd.to_datetime(df_data['Order Date'])
df_data.loc[:, 'Year'] = df_data['Order Date'].dt.year
df_data.loc[:, 'Month'] = df_data['Order Date'].dt.month
df_data.loc[:, 'Day'] = df_data['Order Date'].dt.day

# %%
df_data
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 5909    31907  CA-2013-161816 2013-04-29 2013-05-02     First Class
# 5914    24261   ID-2013-79432 2013-12-11 2013-12-14    Second Class
# 5915    33355  CA-2014-120376 2014-12-23 2014-12-26     First Class
# 5921    24245   IN-2014-22606 2014-08-11 2014-08-11        Same Day
# 5922    30952   ID-2014-85529 2014-05-08 2014-05-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 51284   24175   IN-2014-57662 2014-08-05 2014-08-10  Standard Class
# 51285   29002   IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51287   40470  US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596  MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147  MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID        Customer Name      Segment        City  \
# 5909     NB-18655            Nona Balk    Corporate      Dallas
# ...

# %%
df_data= df_data.drop(columns=['Row ID','Order Date','Ship Date','Customer Name'])

# %%
# df_data= df_data.drop(columns=['Customer ID','Product ID','Region'])

# %%
df_data
# Out:
#              Order ID       Ship Mode Customer ID      Segment        City  \
# 5909   CA-2013-161816     First Class    NB-18655    Corporate      Dallas
# 5914    ID-2013-79432    Second Class    JK-15325    Corporate    Adelaide
# 5915   CA-2014-120376     First Class    TP-21130     Consumer     Detroit
# 5921    IN-2014-22606        Same Day    RC-19960     Consumer     Wenzhou
# 5922    ID-2014-85529  Standard Class    AG-10300    Corporate    Auckland
# ...               ...             ...         ...          ...         ...
# 51284   IN-2014-57662  Standard Class    DB-13270  Home Office  Townsville
# 51285   IN-2014-62366        Same Day    KE-16420    Corporate        Kure
# 51287  US-2013-155768        Same Day    LB-16795  Home Office      Oxnard
# 51288  MX-2012-140767  Standard Class    RB-19795  Home Office    Valinhos
# 51289  MX-2012-134460    Second Class    MC-18100     Consumer    Tipitapa
#
# ...

# %%
# categorical_columns=['Order ID', 'Ship Mode', 'Customer ID',  'Segment','City', 'State', 'Country', 'Market', 'Region', 'Product ID','Category', 'Sub-Category', 'Product Name', 'Order Priority']
# df_encoded=pd.get_dummies(data=df_data  ,prefix='OHE',prefix_sep='_',columns=categorical_columns,drop_first=True,dtype='int8')

# %%
categorical_columns=['Order ID', 'Ship Mode', 'Customer ID',  'Segment','City', 'State', 'Country', 'Market', 'Region', 'Product ID','Category', 'Sub-Category', 'Product Name', 'Order Priority']
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Iterate over each categorical column and apply label encoding
for column in categorical_columns:
    df_data[column] = label_encoder.fit_transform(df_data[column])

# Now, the categorical columns are label encoded

# %%
df_data
# Out:
#        Order ID  Ship Mode  Customer ID  Segment  City  State  Country  \
# 5909       2660          0         1098        1   764    855      130
# 5914       8710          2          749        1    18    801        6
# 5915       3188          0         1507        0   804    551      130
# 5921      11501          1         1250        0  3132    946       26
# 5922       9218          3           37        1   185     76       89
# ...         ...        ...          ...      ...   ...    ...      ...
# 51284     11987          3          380        2  2934    709        6
# 51285     12049          1          849        1  1530    355       65
# 51287     19620          1          893        2  2163    160      130
# 51288     15072          3         1240        2  3002    832       17
# 51289     15015          2          975        0  2900    511       90
#
#        Market  Region  Product ID  ...  Product Name    Sales  Quantity  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
# standard_scale = StandardScaler()
# df_encoded_stdScale = standard_scale.fit_transform(df_encoded[['Sales','Profit','Shipping Cost','Quantity','Discount']])
# df_encoded_stdScale[:5]

# %%
dates = pd.date_range(start='2011-01-01', end='2014-12-31')
df = pd.DataFrame({'Date': dates, 'Data': np.random.randint(0, 2, len(dates))})

# Function to check if a given date is a weekday
def is_weekday(date):
    return date.weekday() < 5

# Function to check if a given date is a holiday
def is_holiday(date):
    holidays = [(1, 1), (12, 25)]  # New Year's Day, Independence Day, Christmas Day
    return (date.month, date.day) in holidays

# Process data for each year
years_data = {}
for year in range(2011, 2015):
    year_mask = (df['Date'].dt.year == year)
    year_df = df[year_mask].copy()  # Extract data for the current year

    # Check weekdays and holidays
    year_df['Weekday'] = year_df['Date'].apply(lambda x: 1 if is_weekday(x) else 0)
    year_df['Holiday'] = year_df.apply(lambda row: 0 if row['Weekday'] == 1 and is_holiday(row['Date']) == 0 else 1, axis=1)

    # Store processed data for the year
    years_data[year] = year_df

# Example usage: Access data for a specific year
print("Data for 2011:")
print(years_data)
# Out:
# Data for 2011:
# {2011:           Date  Data  Weekday  Holiday
# 0   2011-01-01     0        0        1
# 1   2011-01-02     1        0        1
# 2   2011-01-03     1        1        0
# 3   2011-01-04     1        1        0
# 4   2011-01-05     0        1        0
# ..         ...   ...      ...      ...
# 360 2011-12-27     1        1        0
# 361 2011-12-28     0        1        0
# 362 2011-12-29     0        1        0
# 363 2011-12-30     0        1        0
# 364 2011-12-31     0        0        1
#
# [365 rows x 4 columns], 2012:           Date  Data  Weekday  Holiday
# 365 2012-01-01     0        0        1
# 366 2012-01-02     0        1        0
# 367 2012-01-03     1        1        0
# 368 2012-01-04     1        1        0
# 369 2012-01-05     0        1        0
# ..         ...   ...      ...      ...
# 726 2012-12-27     1        1        0
# 727 2012-12-28     1        1        0
# 728 2012-12-29     0        0        1
# 729 2012-12-30     1        0        1
# ...

# %%
all_years_data = pd.concat(years_data.values(), ignore_index=True)
all_years_data
# Out:
#            Date  Data  Weekday  Holiday
# 0    2011-01-01     0        0        1
# 1    2011-01-02     1        0        1
# 2    2011-01-03     1        1        0
# 3    2011-01-04     1        1        0
# 4    2011-01-05     0        1        0
# ...         ...   ...      ...      ...
# 1456 2014-12-27     0        0        1
# 1457 2014-12-28     0        0        1
# 1458 2014-12-29     0        1        0
# 1459 2014-12-30     0        1        0
# 1460 2014-12-31     1        1        0
#
# [1461 rows x 4 columns]

# %%
all_years_data['Holiday'].value_counts()
# Out:
# Holiday
# 0    1038
# 1     423
# Name: count, dtype: int64

# %%
# a= a.drop(columns=['Data'])

# %%
# a

# %%
import pandas as pd
df1 = df_data
df2 = all_years_data

# Assuming you have two DataFrames df1 and df2
# df1 contains 'yr', 'month', and 'day' columns
# df2 contains 'date' column with jumbled dates

# Combine 'Year', 'Month', and 'Day' columns into a single date column in df1
df1['Date'] = pd.to_datetime(df1[['Year', 'Month', 'Day']]) 
# Sort df1 based on the new 'Date' column
df1_sorted = df1.sort_values(by='Date')

# Sort df2 based on the 'date' column
df2_sorted = df2.sort_values(by='Date')

# Merge the two DataFrames based on the 'date' column
merged_df = pd.merge(df1_sorted, df2_sorted, on='Date', how='outer')

# Now, merged_df contains the columns from both df1 and df2, mapped to the same dates

# %%
merged_df
# Out:
#        Order ID  Ship Mode  Customer ID  Segment    City  State  Country  \
# 0        7859.0        2.0        119.0      0.0   454.0  145.0     56.0
# 1        9515.0        3.0        737.0      0.0  3102.0  606.0      6.0
# 2        9515.0        3.0        737.0      0.0  3102.0  606.0      6.0
# 3        9515.0        3.0        737.0      0.0  3102.0  606.0      6.0
# 4       12803.0        2.0        537.0      2.0  2765.0  816.0    119.0
# ...         ...        ...          ...      ...     ...    ...      ...
# 36347   17031.0        1.0       1236.0      2.0  1774.0  511.0     90.0
# 36348    3593.0        3.0       1198.0      0.0  2055.0  607.0    130.0
# 36349   16512.0        2.0        310.0      0.0  1774.0  511.0     90.0
# 36350   12291.0        3.0       1001.0      0.0  1380.0  403.0     26.0
# 36351   16483.0        3.0        681.0      2.0  2430.0  838.0     79.0
#
#        Market  Region  Product ID  ...  Profit  Shipping Cost  Order Priority  \
# ...

# %%
merged_df = merged_df.drop(columns=['Date','Data','Year'])

# %%
merged_df
# Out:
#        Order ID  Ship Mode  Customer ID  Segment    City  State  Country  \
# 0        7859.0        2.0        119.0      0.0   454.0  145.0     56.0
# 1        9515.0        3.0        737.0      0.0  3102.0  606.0      6.0
# 2        9515.0        3.0        737.0      0.0  3102.0  606.0      6.0
# 3        9515.0        3.0        737.0      0.0  3102.0  606.0      6.0
# 4       12803.0        2.0        537.0      2.0  2765.0  816.0    119.0
# ...         ...        ...          ...      ...     ...    ...      ...
# 36347   17031.0        1.0       1236.0      2.0  1774.0  511.0     90.0
# 36348    3593.0        3.0       1198.0      0.0  2055.0  607.0    130.0
# 36349   16512.0        2.0        310.0      0.0  1774.0  511.0     90.0
# 36350   12291.0        3.0       1001.0      0.0  1380.0  403.0     26.0
# 36351   16483.0        3.0        681.0      2.0  2430.0  838.0     79.0
#
#        Market  Region  Product ID  ...    Sales  Quantity  Discount  Profit  \
# ...

# %%
merged_df.columns
# Out:
# Index(['Order ID', 'Ship Mode', 'Customer ID', 'Segment', 'City', 'State',
#        'Country', 'Market', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost', 'Order Priority', 'Month', 'Day', 'Weekday',
#        'Holiday'],
#       dtype='object')

# %%
Columns=['Order ID', 'Ship Mode', 'Customer ID', 'Segment', 'City', 'State',
       'Country', 'Market', 'Region', 'Product ID', 'Category', 'Sub-Category',
       'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
       'Shipping Cost', 'Order Priority', 'Month', 'Day', 'Weekday',
       'Holiday']

from sklearn.preprocessing import MinMaxScaler

minmax_scale = MinMaxScaler()
columns_to_scale = ['Order ID', 'Ship Mode', 'Customer ID', 'Segment', 'City', 'State',
                    'Country', 'Market', 'Region', 'Product ID', 'Category', 'Sub-Category',
                    'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
                    'Shipping Cost', 'Order Priority', 'Month', 'Day', 'Weekday',
                    'Holiday']
merged_df_scaled = minmax_scale.fit_transform(merged_df[columns_to_scale])
merged_df_scaled[:5]
# Replace the original columns with the scaled values
for i, col in enumerate(columns_to_scale):
    merged_df[col] = merged_df_scaled[:, i]

# Display the first few rows of the updated DataFrame
merged_df.head()
# Out:
#    Order ID  Ship Mode  Customer ID  Segment      City     State   Country  \
# 0  0.386648   0.666667     0.075412      0.0  0.138626  0.152311  0.414815
# 1  0.468120   1.000000     0.467047      0.0  0.947176  0.636555  0.044444
# 2  0.468120   1.000000     0.467047      0.0  0.947176  0.636555  0.044444
# 3  0.468120   1.000000     0.467047      0.0  0.947176  0.636555  0.044444
# 4  0.629883   0.666667     0.340304      1.0  0.844275  0.857143  0.881481
#
#      Market    Region  Product ID  ...     Sales  Quantity  Discount  \
# 0  0.500000  0.416667    0.790458  ...  0.112243     0.375       0.0
# 1  0.000000  0.750000    0.134121  ...  0.194189     0.500       0.2
# 2  0.000000  0.750000    0.615061  ...  0.093496     0.125       0.2
# 3  0.000000  0.750000    0.746375  ...  0.205728     0.250       0.2
# 4  0.666667  0.583333    0.606525  ...  0.075613     0.250       1.0
#
#      Profit  Shipping Cost  Order Priority  Month  Day  Weekday  Holiday
# ...

# %%
merged_df.isnull().sum()
# Out:
# Order ID          41
# Ship Mode         41
# Customer ID       41
# Segment           41
# City              41
# State             41
# Country           41
# Market            41
# Region            41
# Product ID        41
# Category          41
# Sub-Category      41
# Product Name      41
# Sales             41
# Quantity          41
# Discount          41
# Profit            41
# Shipping Cost     41
# Order Priority    41
# Month             41
# Day               41
# Weekday            0
# Holiday            0
# dtype: int64

# %%
# Assuming df is your DataFrame
merged_df.dropna(inplace=True)
merged_df.dropna(how='all', inplace=True)

# %%
merged_df.isnull().sum()
# Out:
# Order ID          0
# Ship Mode         0
# Customer ID       0
# Segment           0
# City              0
# State             0
# Country           0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# Month             0
# Day               0
# Weekday           0
# Holiday           0
# dtype: int64

# %%
# numeric_df = merged_df .select_dtypes(include=['float64', 'int64'])

# # Calculate correlations on numeric columns
# corr = numeric_df.corr()

# # Plot heatmap
#  corr

# %%
# LINEAR REGRESSION

# %%
X = merged_df.drop(columns=['Profit'],axis=1)
y = merged_df['Profit']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=24)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# %%
tree = DecisionTreeRegressor(max_depth=4,max_features=4)

tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=4, max_features=4)

# %%
predictions = tree.predict(X_test)

# %%
df=pd.DataFrame({'Actual':y_test, 'Predicted':predictions})
df.head(5)
# Out:
#          Actual  Predicted
# 24946  0.436029   0.599729
# 5198   0.348727   0.305666
# 11640  0.377140   0.417216
# 29501  0.543534   0.437280
# 10474  0.481137   0.417216

# %%
# Evaluating the Prediction Accuracy
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test,predictions))
print('Mean Squared Error:', metrics.mean_squared_error(y_test,predictions))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test,predictions)))
print('r2_score:', metrics.r2_score(y_test,predictions))
# Out:
# Mean Absolute Error: 0.09576744200782988
# Mean Squared Error: 0.01929798412607236
# Root Mean Squared Error: 0.13891718441601228
# r2_score: 0.2422483410784464

# %%
tree.feature_importances_
pd.Series(tree.feature_importances_,index=X.columns).sort_values(ascending=False)
# Out:
# Shipping Cost     0.559647
# Sales             0.195817
# Order ID          0.090532
# Discount          0.083889
# Sub-Category      0.020458
# Region            0.015543
# Market            0.014404
# Category          0.006468
# State             0.006227
# Quantity          0.004617
# Month             0.002399
# Customer ID       0.000000
# Weekday           0.000000
# Day               0.000000
# Order Priority    0.000000
# City              0.000000
# Segment           0.000000
# Country           0.000000
# Product Name      0.000000
# Ship Mode         0.000000
# Product ID        0.000000
# Holiday           0.000000
# dtype: float64

# %%
# from sklearn.tree import export_graphviz

# dot_data = export_graphviz(tree, filled=True, rounded=True, feature_names=X.columns, out_file=None)

# %%
# !pip install graphviz

# import graphviz
# # plt.figure(figsize=(8,5))
# graphviz.Source(dot_data)


# import os
# from graphviz import Source

# # Set the path to the Graphviz executable
# os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

# %%
# import matplotlib.pyplot as plt
# plt.figure(figsize=(8,5))
# graphviz.Source(dot_data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\graphviz\backend\execute.py:76, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      75         kwargs['stdout'] = kwargs['stderr'] = subprocess.PIPE
# ---> 76     proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      77 else:
#
# File ~\anaconda3\Lib\site-packages\graphviz\backend\execute.py:96, in _run_input_lines(cmd, input_lines, kwargs)
#      95 def _run_input_lines(cmd, input_lines, *, kwargs):
# ---> 96     popen = subprocess.Popen(cmd, stdin=subprocess.PIPE, **kwargs)
#      98     stdin_write = popen.stdin.write
#
# ...

# %%
# from graphviz import Source

# # Your Graphviz code
# dot_code =

# # Save the graph as an image file
# graph = Source(dot_code)
# graph.render(filename='graph', format='png', cleanup=True)

# # Display the image in the notebook
# from IPython.display import Image
# Image(filename='graph.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[150], line 8
#       6 # Save the graph as an image file
#       7 graph = Source(dot_code)
# ----> 8 graph.render(filename='graph', format='png', cleanup=True)
#      10 # Display the image in the notebook
#      11 from IPython.display import Image
#
# File ~\anaconda3\Lib\site-packages\graphviz\_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
# ...

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [{"max_depth":[3,4,5, None], "max_features":[3,4,5,6,7]}]

# %%
gs = GridSearchCV(estimator=DecisionTreeRegressor(random_state=123),param_grid = param_grid,cv=10)

# %%
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(random_state=123),
#              param_grid=[{'max_depth': [3, 4, 5, None],
#                           'max_features': [3, 4, 5, 6, 7]}])

# %%
gs.cv_results_['rank_test_score']
# Out:
# array([15,  6,  8, 12,  4, 13, 10,  3, 14,  1,  7,  9,  5, 11,  2, 20, 19,
#        18, 16, 17])

# %%
gs.best_estimator_
# Out:
# DecisionTreeRegressor(max_depth=4, max_features=7, random_state=123)

# %%
tree = DecisionTreeRegressor(max_depth=3,max_features=4)

tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3, max_features=4)

# %%
predictions = tree.predict(X_test)

# %%
df=pd.DataFrame({'Actual':y_test, 'Predicted':predictions})
df.head(5) #Check the top 5 predictions and actual values.
# Out:
#          Actual  Predicted
# 24946  0.436029   0.530034
# 5198   0.348727   0.361282
# 11640  0.377140   0.411735
# 29501  0.543534   0.411735
# 10474  0.481137   0.411735

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test,predictions))
print('Mean Squared Error:', metrics.mean_squared_error(y_test,predictions))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test,predictions)))
print('r2_score:', metrics.r2_score(y_test,predictions))
# Out:
# Mean Absolute Error: 0.10042005498623338
# Mean Squared Error: 0.021660322497033025
# Root Mean Squared Error: 0.14717446278832827
# r2_score: 0.14948912810391446

# %%
gs.cv_results_['params']
# Out:
# [{'max_depth': 3, 'max_features': 3},
#  {'max_depth': 3, 'max_features': 4},
#  {'max_depth': 3, 'max_features': 5},
#  {'max_depth': 3, 'max_features': 6},
#  {'max_depth': 3, 'max_features': 7},
#  {'max_depth': 4, 'max_features': 3},
#  {'max_depth': 4, 'max_features': 4},
#  {'max_depth': 4, 'max_features': 5},
#  {'max_depth': 4, 'max_features': 6},
#  {'max_depth': 4, 'max_features': 7},
#  {'max_depth': 5, 'max_features': 3},
#  {'max_depth': 5, 'max_features': 4},
#  {'max_depth': 5, 'max_features': 5},
#  {'max_depth': 5, 'max_features': 6},
#  {'max_depth': 5, 'max_features': 7},
#  {'max_depth': None, 'max_features': 3},
#  {'max_depth': None, 'max_features': 4},
#  {'max_depth': None, 'max_features': 5},
#  {'max_depth': None, 'max_features': 6},
#  {'max_depth': None, 'max_features': 7}]

# %%
# # Applying 5-Fold Cross Validation
# from sklearn.model_selection import cross_val_score
# scores = cross_val_score(lin_reg, X_train, y_train, cv = 5, scoring='r2')

# print('Cross-validation scores:{}'.format(scores))

# %%
# # compute Average cross-validation score

# print('Average cross-validation score: {:.4f}'.format(scores.mean()))

# %%
# from sklearn.linear_model import Lasso

# parameters = {'alpha': [1e-15, 1e-10, 1e-8, 1e-4, 1e-3, 1e-2, 1, 5, 10, 20]}
# lasso = Lasso()

# grid_search = GridSearchCV(estimator=lasso, param_grid=parameters, scoring='r2', cv=5)
# grid_search.fit(X_train, y_train)

# print("Best parameters found: ", grid_search.best_params_)
# print("Best R2 score found: ", grid_search.best_score_)

# %%
# from sklearn.linear_model import Ridge
# from sklearn.model_selection import GridSearchCV

# parameters = {'alpha': [1e-15, 1e-10, 1e-8, 1e-4, 1e-3, 1e-2, 1, 5, 10, 20]}
# ridge = Ridge()

# grid_search = GridSearchCV(estimator=ridge, param_grid=parameters, scoring='r2', cv=5)
# grid_search.fit(X_train, y_train)

# print("Best parameters found: ", grid_search.best_params_)
# print("Best R2 score found: ", grid_search.best_score_)
